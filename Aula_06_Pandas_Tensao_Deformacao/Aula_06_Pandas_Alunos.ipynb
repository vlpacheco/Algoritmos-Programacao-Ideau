# %% [markdown]
# ________________________________________________________________________________
# Aula 05
#
# 1. Bibliotecas
#
# 2. Biblioteca Numpy
#
# 3. Biblioteca Pandas
# https://www.geeksforgeeks.org/python-pandas-dataframe/
#
# ________________________________________________________________________________

# %% [markdown]
# # **1. Bibliotecas**

# %% [markdown]
# Uma biblioteca é um **conjunto de códigos** sistematicamente reutilizáveis que definem funções geralmente concentradas em torno de um mesmo tópico. Por exemplo, em uma biblioteca computacional de Álgebra Linear, espera-se encontrar disponíveis funções que realizem multiplicação matriz-matriz, matriz-vetor, cálculo de autovalores e autovetores, norma, matriz inversa e decomposições, por exemplo, sem que o usuário tenha que desenvolver um código que implemente tais operações. Lembre-se de que computadores trabalham em base binária, e nessa base são desenvolvidas as quatro operações básicas: adição, subtração, multiplicação e divisão. Para tal, são utilizadas técnicas de aritmética binária, acessos e leitura a blocos de memória, processamentos em ULA (Unidade Lógica Aritmética) e gravação em memória, em geral sem que o operador precise se preocupar com os detalhes operacionais dessas operações.

# %% [markdown]
# # **2. Numpy e Arrays**

# %% [markdown]
# Em computação científica é muito comum o uso de arrays. Arrays são estruturas de dados semelhantes às listas do Python, mas não tão flexíveis. Em um array todos os elementos devem ser de um mesmo tipo, tipicamente numérico, como int ou float. Além disso, o tamanho de um array não pode ser modificado, ao contrário de listas que podem crescer dinamicamente. Em contrapartida, o uso de arrays é **muito mais eficiente e facilita a computação de grandes volumes de dados** numéricos. Isso faz com que arrays sejam particularmente úteis em computação científica.
#
# Para trabalhar com arrays em Python vamos utilizar o módulo NumPy (Numeric Python). O NumPy define a classe ndarray para encapsular arrays de n dimensões. Os arrays do NumPy tem tamanho fixo, assim, para se mudar o tamanho de um ndarray, cria-se um novo array e o original é removido.
#
# fonte 01: https://www.numpy.org/doc
#
# fonte 02: https://panda.ime.usp.br/

# %% [markdown]
# #2.1 Definicao de Vetor, Matriz, Tensor e Arrays
#
# ![tensor.png](data:image/png;base64,...)
#
#
# ![arrays.png](data:image/png;base64,...)

# %% [markdown]
# #2.2 Numpy na criacao de matrizes e vetores
#
# Exemplo 01) Definindo matrizes e vetores com uso da biblioteca numpy.
# Definir a matriz A e o vetor b dados a seguir:
#
# $A_{} =
#  \begin{pmatrix}
#   {3} & {-1} & {0} \\
#   {-2} & {4} & {-3} \\
#   {0} & {-1} & {1} \\ &{}
#  \end{pmatrix}$
#
#  $b_{} =
#  \begin{pmatrix}
#   {1}\\
#   {2}\\
#   {3}\\ &{}
#  \end{pmatrix}$

# %% [markdown]
# Exemplo 01) Calcule, com o auxílio da biblioteca Numpy, as expressoes:
#
# a) $x=e^2$
#
# b) ln(x)

# %% [markdown]
# Exemplo 02) Funcoes Trigonométricas.
# Calcule $\sin(\frac{\pi}{4})$, $\cos(\frac{\pi}{4})$, $\tan(\frac{\pi}{4})$

# %% [markdown]
# Exemplo 03) Arredondamento para inteiro mais próximo.
# Arredondar x = 1,203945

# %% [markdown]
# #**3 Biblioteca Pandas**
#
# fonte: https://pandas.pydata.org

# %% [markdown]
# A manipulação e visualização de dados por meio de tabelas pode ser feita através da biblioteca Pandas. Importação da biblioteca sob o "código" pd:

# %% [markdown]
# **DataFrame:** São objetos de duas dimensões, no qual cada coluna pode possuir um tipo primário diferente. São utilizados para armazenar bases de dados **de todos os formatos.**

# %% [markdown]
# ![Screen Shot 2021-09-13 at 14.21.44.png](data:image/png;base64,...)

# %% [markdown]
# ________________________________________________________________
# **CSV File:**
# Comma-separated values (ou CSV) é um formato de arquivo que armazena dados tabelados, cujo grande uso data da época dos mainframes. Por serem bastante simples, arquivos .csv são comuns em todas as plataformas de computador.
#
# É um implementação particular de arquivos de texto separados por um delimitador, que usa a vírgula e a quebra de linha para separar os valores. O formato também usa as aspas em campos no qual são usados os caracteres reservados (vírgula e quebra de linha). Essa robustez no formato torna o CSV mais amplo que outros formatos digitais do mesmo segmento.
# ________________________________________________________________

# %% [markdown]
# **Pandas:** A biblioteca possui uma função read_csv para leitura de arquivos texto.

# %% [markdown]
# ______________________________________________________

# %% [markdown]
# 3.1 Criando DataFrames

# %% [markdown]
# #4 Aplicacao Tensao x Deformacao - Alumínio

# %% [markdown]
# Considere a aplicacao do ensaio de ruptura por tracao de um corpo de prova de aluminio, com diametro de 12,8 mm e comprimento inicial de 50,8 mm. Com os resultados encontrados no arquivo: "aluminio_1.csv". Para isso, faça:
#
# a) Carregue os dados no ambiente Google Colab;
#
# b) Converta a carga de N para KN;
#
# c) Encontre a tensao equivalente em MPa;
#
# d) Encontre a deformacao linear (ΔL/L) (ε);
#
# e) Plote o graficos: N vs deformacao (mm); N vs deformacao (cm); KN vs deformacao (mm); KN vs deformacao (cm); MPa vs deformacao (mm).
